# %% [markdown]
# # 1. Import required libraries and read the dataset.

# %%
import pandas as pd

# %%
df = pd.read_csv('honeyproduction (1).csv')
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.sample(8)
# Out:
#     state    numcol  yieldpercol   totalprod     stocks  priceperlb  \
# 228    IA   32000.0           59   1888000.0   868000.0        1.42
# 27     NC    8000.0           59    472000.0   151000.0        1.38
# 143    LA   45000.0          106   4770000.0   572000.0        0.60
# 132    CA  460000.0           61  28060000.0  7857000.0        0.69
# 31     OR   50000.0           45   2250000.0  1620000.0        0.90
# 558    KS    7000.0           44    308000.0   117000.0        2.15
# 1      AZ   55000.0           60   3300000.0  1485000.0        0.64
# 8      ID  120000.0           50   6000000.0  2220000.0        0.65
#
#       prodvalue  year
# 228   2681000.0  2003
# 27     651000.0  1998
# 143   2862000.0  2001
# 132  19361000.0  2001
# 31    2025000.0  1998
# 558    662000.0  2011
# 1     2112000.0  1998
# 8     3900000.0  1998

# %%
df.shape
# Out:
# (626, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
df.isnull().sum()
# Out:
# state          0
# numcol         0
# yieldpercol    0
# totalprod      0
# stocks         0
# priceperlb     0
# prodvalue      0
# year           0
# dtype: int64

# %%
df.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %%
df.dtypes
# Out:
# state           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %%
df.nunique()
# Out:
# state           44
# numcol         148
# yieldpercol     95
# totalprod      517
# stocks         500
# priceperlb     210
# prodvalue      589
# year            15
# dtype: int64

# %% [markdown]
# # 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df.groupby(['year'])['year'].count(),autopct = '%0.1f%%',labels = df.groupby(['year'])['year'].count().index,shadow = True);
plt.title('Percentage distribution of the data in each year');

# %% [markdown]
# # 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
import seaborn as sns
sns.displot(df['priceperlb']);
plt.title('Distribution of price per lb');
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# inference 
# Our majority of data is before the mean (1.409569), our median (1.360000) is before the mean, and it is positively skewed. Our majority of data is between the range (0.7 to 2)

# %% [markdown]
# #  5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
sns.scatterplot(x=df['numcol'],y = df['prodvalue']);
plt.title('Relationship between numcol and prodvalue');

# %%
# inference
# The number of colonies and the production value are positively correlated since there is linear increase between both.The majority of the data ranges from 0 to 100,000.

# %% [markdown]
# # 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
sns.boxplot(x=df['year'],y = df['prodvalue']);
plt.title('Relationship between year and prodvalue');

# %%
# inference 
# Years such as 2003,2008,2009,2010,2012 has the more outliers and the 2010 has the highest outliers. Almost majority of the years have the same range of mean.

# %% [markdown]
# # 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
sns.pairplot(df,vars = ['numcol','yieldpercol','totalprod','prodvalue','year']);
plt.title('Relationship between multiple pairs');
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# inference 
# Some of the pairs have no association, such as (yieldpercol,numcol), (prodvalue, yieldpercol), and (yieldpercol,totalprod). These pairs have a positive correlation because as the x axis increases, so does the y axis. Thus the two variables (totalprod,numcol), (prodvalue,numcol), and (totalprod,prodvalue) are all flowing in the same direction.

# %% [markdown]
# # 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
data = df[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']]

# %%
sns.heatmap(data.corr(),annot = True);

# %%
# inference
# The correlation value is high for the totalprod and numcol(0.95). The least positive correlation is between the totalprod and the yieldpercol(0.4). There is also some negatively correlated pairs they are mostly pair with the priceperlb such as numcol, yieldpercol,totalprod ,prodvalue and stocks .
